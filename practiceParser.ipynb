# %%
import json
import emoji

# %%
with open('sessions.json', 'r') as f:
  input_json = json.load(f)

# %%
# Serializing json
json_object = json.dumps(input_json)
 
# Writing to sample.json
with open("session.js", "w") as outfile:
    outfile.write(json_object)

# %%
json_object
# Out:
# '[{"id": 0, "datetime": "2024-01-12 09:41:32", "player": "Bez", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Hey team!:rocket: Can you believe it\'s been 8 fantastic years for Online Boutique?", "date": "2024-01-12"}, {"id": 1, "datetime": "2024-01-12 09:41:36", "player": "Bez", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": " Before we dive into anniversary celebrations, let\'s give a warm welcome to Maya, our new Security Analyst. She\'s got 5 years of cybersecurity expertise under her belt! :clap: ", "date": "2024-01-12"}, {"id": 2, "datetime": "2024-01-12 09:41:41", "player": "Maya", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Hi everyone! :raised_hand_with_fingers_splayed: Thrilled to be here, especially on such a special occasion. Let\'s make Online Boutique even successful and secure together!", "date": "2024-01-12"}, {"id": 3, "datetime": "2024-01-12 09:41:44", "player": "Tinus", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Welcome, Maya! Your experience will elevate our cybersecurity efforts.", "date": "2024-01-12"}, {"id": 4, "datetime": "2024-01-12 09:41:48", "player": "Tanya", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Excited to have you, Maya! Bez has been very excited to have you on the team.", "date": "2024-01-12"}, {"id": 5, "datetime": "2024-01-12 09:41:51", "player": "Daniel", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Impressive! Eager to learn from you, Maya.", "date": "2024-01-12"}, {"id": 6, "datetime": "2024-01-12 09:41:55", "player": "Shay", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": ":+1: Welcome Maya, pleasure meeting you.", "date": "2024-01-12"}, {"id": 7, "datetime": "2024-01-12 09:41:58", "player": "Bob", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Hi Maya! Your experience is top-notch. Cheers to you and to Online Boutique\'s 8-year anniversary! :partying_face: :tada:", "date": "2024-01-12"}, {"id": 8, "datetime": "2024-01-12 09:42:01", "player": "Maya", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Thanks for the warm welcome! Excited for the celebration and our anniversary party.", "date": "2024-01-12"}, {"id": 9, "datetime": "2024-01-12 09:42:11", "player": "UptimeLabs", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Start lvl 18", "date": "2024-01-12"}, {"id": 10, "datetime": "2024-01-12 09:42:19", "player": "conail@uptimelabs.io", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Clicked Start button", "date": "2024-01-12"}, {"id": 11, "datetime": "2024-01-12 09:42:21", "player": "Bez", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "We are all so glad you have joined us Maya", "date": "2024-01-12"}, {"id": 12, "datetime": "2024-01-12 09:42:23", "player": "Tinus", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Hold on, team. Quick check-in. Is anyone else experiencing internet problems or slow connectivity?", "date": "2024-01-12"}, {"id": 13, "datetime": "2024-01-12 09:42:26", "player": "Shay", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Internet\'s definitely sluggish, was loading up github and it took ages to load", "date": "2024-01-12"}, {"id": 14, "datetime": "2024-01-12 09:42:29", "player": "Bez", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Perhaps it could be due to the increase of sales we have been having with this anniversary sale?", "date": "2024-01-12"}, {"id": 15, "datetime": "2024-01-12 09:42:31", "player": "Hamed", "scenario": "online-boutique", "level": 18.0, "session_id": 1453.0, "message": "Hey team, we\'ve seen some weird traffic from our data centre network in the l ...

# %%
input_json
# Out:
# [{'id': 0,
#   'datetime': '2024-01-12 09:41:32',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': "Hey team!:rocket: Can you believe it's been 8 fantastic years for Online Boutique?",
#   'date': '2024-01-12'},
#  {'id': 1,
#   'datetime': '2024-01-12 09:41:36',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': " Before we dive into anniversary celebrations, let's give a warm welcome to Maya, our new Security Analyst. She's got 5 years of cybersecurity expertise under her belt! :clap: ",
#   'date': '2024-01-12'},
#  {'id': 2,
#   'datetime': '2024-01-12 09:41:41',
#   'player': 'Maya',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': "Hi everyone! :raised_hand_with_fingers_splayed: Thrilled to be here, especially on such a special occasion. Let's make Online Boutique even successful and secure together!",
#   'date': '2024-01-12'},
#  {'id': 3,
#   'datetime': '2024-01-12 09:41:44',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Welcome, Maya! Your experience will elevate our cybersecurity efforts.',
#   'date': '2024-01-12'},
#  {'id': 4,
#   'datetime': '2024-01-12 09:41:48',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Excited to have you, Maya! Bez has been very excited to have you on the team.',
#   'date': '2024-01-12'},
#  {'id': 5,
#   'datetime': '2024-01-12 09:41:51',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Impressive! Eager to learn from you, Maya.',
#   'date': '2024-01-12'},
#  {'id': 6,
#   'datetime': '2024-01-12 09:41:55',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': ':+1: Welcome Maya, pleasure meeting you.',
#   'date': '2024-01-12'},
#  {'id': 7,
#   'datetime': '2024-01-12 09:41:58',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': "Hi Maya! Your experience is top-notch. Cheers to you and to Online Boutique's 8-year anniversary! :partying_face: :tada:",
#   'date': '2024-01-12'},
#  {'id': 8,
#   'datetime': '2024-01-12 09:42:01',
#   'player': 'Maya',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Thanks for the warm welcome! Excited for the celebration and our anniversary party.',
#   'date': '2024-01-12'},
#  {'id': 9,
#   'datetime': '2024-01-12 09:42:11',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Start lvl 18',
#   'date': '2024-01-12'},
#  {'id': 10,
#   'datetime': '2024-01-12 09:42:19',
#   'player': 'conail@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Clicked Start button',
#   'date': '2024-01-12'},
#  {'id': 11,
#   'datetime': '2024-01-12 09:42:21',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'We are all so glad you have joined us Maya',
#   'date': '2024-01-12'},
#  {'id': 12,
#   'datetime': '2024-01-12 09:42:23',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Hold on, team. Quick check-in. Is anyone else experiencing internet problems or slow connectivity?',
#   'date': '2024-01-12'},
#  {'id': 13,
#   'datetime': '2024-01-12 09:42:26',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': "Internet's definitely sluggish, was loading up github and it took ages to load",
#   'date': '2024-01-12'},
#  {'id': 14,
#   'datetime': '2024-01-12 09:42:29',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Perhaps it could be due to the increase of sales we have been having with this anniversary sale?',
#   'date': '2024-01-12'},
#  {'id': 15,
#   'datetime': '2024-01-12 09:42:31',
#   'player': 'Hamed',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': "Hey team, we've seen some weird traffic from our data centre network in the last couple of days, it's been mostly minor but never as bad compared to now although",
#   'date': '2024-01-12'},
#  {'id': 16,
#   'datetime': '2024-01-12 09:42:35',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Hamed and I will have been monitoring outbound traffic. Checking for anomalies again.',
#   'date': '2024-01-12'},
#  {'id': 17,
#   'datetime': '2024-01-12 09:42:42',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'I will try to place an order and check the platform.',
#   'date': '2024-01-12'},
#  {'id': 18,
#   'datetime': '2024-01-12 09:42:52',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Just ran a test on my internet speed.',
#   'date': '2024-01-12'},
#  {'id': 19,
#   'datetime': '2024-01-12 09:42:55',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': ' ',
#   'date': '2024-01-12'},
#  {'id': 20,
#   'datetime': '2024-01-12 09:44:04',
#   'player': 'Maya',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'the infected switch has been successfully changed over',
#   'date': '2024-01-12'},
#  {'id': 21,
#   'datetime': '2024-01-12 09:44:14',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Good job, can we confirm @Conail Tierney?',
#   'date': '2024-01-12'},
#  {'id': 22,
#   'datetime': '2024-01-12 09:44:43',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Cheers, everyone! Resolving these network issues added a bit of spice to our celebration',
#   'date': '2024-01-12'},
#  {'id': 23,
#   'datetime': '2024-01-12 09:44:45',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Good job team! We managed to keep the anniversary vibe alive despite the detour.',
#   'date': '2024-01-12'},
#  {'id': 24,
#   'datetime': '2024-01-12 09:44:48',
#   'player': 'Hamed',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'High-fives all around!  I will take out that faulty switch as soon as possible.',
#   'date': '2024-01-12'},
#  {'id': 25,
#   'datetime': '2024-01-12 09:44:53',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': "The website's performance is looking solid again ",
#   'date': '2024-01-12'},
#  {'id': 26,
#   'datetime': '2024-01-12 09:44:57',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'The anniversary orders are flowing smoothly now. No hiccups on the code side.',
#   'date': '2024-01-12'},
#  {'id': 27,
#   'datetime': '2024-01-12 09:45:00',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Our customers are back to enjoying the celebration. Happy customers, happy anniversary!',
#   'date': '2024-01-12'},
#  {'id': 28,
#   'datetime': '2024-01-12 09:45:03',
#   'player': 'Maya',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Really great job @Conail Tierney.',
#   'date': '2024-01-12'},
#  {'id': 29,
#   'datetime': '2024-01-12 09:45:06',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Special congratulations to our Incident Manager for steering the ship with finesse and to Maya for your help identifying the faulty switch. Cheers to a remarkable team! :tada:',
#   'date': '2024-01-12'},
#  {'id': 30,
#   'datetime': '2024-01-12 09:45:34',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 18.0,
#   'session_id': 1453.0,
#   'message': 'Start drill retro and feedback',
#   'date': '2024-01-12'},
#  {'id': 31,
#   'datetime': '2024-01-12 10:16:19',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Start Drill',
#   'date': '2024-01-12'},
#  {'id': 32,
#   'datetime': '2024-01-12 10:18:06',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Clicked Start button',
#   'date': '2024-01-12'},
#  {'id': 33,
#   'datetime': '2024-01-12 10:18:07',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'date': '2024-01-12'},
#  {'id': 34,
#   'datetime': '2024-01-12 10:18:14',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Please make sure systems are healthy so we can hit target.',
#   'date': '2024-01-12'},
#  {'id': 35,
#   'datetime': '2024-01-12 10:18:18',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Welcome to the team @Gamunu Balagalla. everone is here to help, how are you finding things so far?',
#   'date': '2024-01-12'},
#  {'id': 36,
#   'datetime': '2024-01-12 10:18:24',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'date': '2024-01-12'},
#  {'id': 37,
#   'datetime': '2024-01-12 10:18:27',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Yes @Gamunu Balagalla is incident manager today, Gamunu Balagalla can you drive this?',
#   'date': '2024-01-12'},
#  {'id': 38,
#   'datetime': '2024-01-12 10:18:37',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'date': '2024-01-12'},
#  {'id': 39,
#   'datetime': '2024-01-12 10:18:39',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'it could be a load issue',
#   'date': '2024-01-12'},
#  {'id': 40,
#   'datetime': '2024-01-12 10:18:39',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Hey, team, how are we doing?',
#   'date': '2024-01-12'},
#  {'id': 41,
#   'datetime': '2024-01-12 10:18:41',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'There were a few deployments this morning',
#   'date': '2024-01-12'},
#  {'id': 42,
#   'datetime': '2024-01-12 10:18:45',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': "I'm at your service",
#   'date': '2024-01-12'},
#  {'id': 43,
#   'datetime': '2024-01-12 10:18:47',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': "I'm online too",
#   'date': '2024-01-12'},
#  {'id': 44,
#   'datetime': '2024-01-12 10:18:57',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'What do I need to tell the angry customers?',
#   'date': '2024-01-12'},
#  {'id': 45,
#   'datetime': '2024-01-12 10:19:05',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'yes Tinus will keep you updated in the business comms channel',
#   'date': '2024-01-12'},
#  {'id': 46,
#   'datetime': '2024-01-12 10:19:31',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Daniel what were the deployments, were you involved in the changes?',
#   'date': '2024-01-12'},
#  {'id': 47,
#   'datetime': '2024-01-12 10:20:05',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Bob, how many customers are impacted? What are they reporting?',
#   'date': '2024-01-12'},
#  {'id': 48,
#   'datetime': '2024-01-12 10:20:07',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'I made changes to the frontend service',
#   'date': '2024-01-12'},
#  {'id': 49,
#   'datetime': '2024-01-12 10:20:23',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': "Reports are coming in from various locations indicating widespread issues with the frontend. Customers are experiencing difficulties with navigation and checkout. We're seeing a high volume of tickets on this.",
#   'date': '2024-01-12'},
#  {'id': 50,
#   'datetime': '2024-01-12 10:20:56',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'ok Daniel can you look into the changes you made and verify everything is working? maybe run quick sanity test',
#   'date': '2024-01-12'},
#  {'id': 51,
#   'datetime': '2024-01-12 10:21:13',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': "I'll check the frontend service and report back shortly.",
#   'date': '2024-01-12'},
#  {'id': 52,
#   'datetime': '2024-01-12 10:21:41',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Bob are the reports coming from all regions? or specific to UK?',
#   'date': '2024-01-12'},
#  {'id': 53,
#   'datetime': '2024-01-12 10:22:12',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'The reports of issues are widespread, not limited to any specific region.',
#   'date': '2024-01-12'},
#  {'id': 54,
#   'datetime': '2024-01-12 10:23:13',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Tanya can you check the change CHG89350?',
#   'date': '2024-01-12'},
#  {'id': 55,
#   'datetime': '2024-01-12 10:23:39',
#   'player': 'gamunu',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': '*Incident Number INC100056:* SEV-1 incident, frontend down.',
#   'date': '2024-01-12'},
#  {'id': 56,
#   'datetime': '2024-01-12 10:23:46',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': "Will do. I'll review the payment service changes and get back to you.",
#   'date': '2024-01-12'},
#  {'id': 57,
#   'datetime': '2024-01-12 10:24:06',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'team is investigating the cause of the issue and will provide an update in 5min',
#   'date': '2024-01-12'},
#  {'id': 58,
#   'datetime': '2024-01-12 10:24:29',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Daniel please update us with your findings',
#   'date': '2024-01-12'},
#  {'id': 59,
#   'datetime': '2024-01-12 10:25:32',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Review complete and frontend looks unhealthy at the moment',
#   'date': '2024-01-12'},
#  {'id': 60,
#   'datetime': '2024-01-12 10:25:33',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Bob keep eye on the business comms. I will update you about the progress in there so you can keep the customers informed',
#   'date': '2024-01-12'},
#  {'id': 61,
#   'datetime': '2024-01-12 10:26:02',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'thanks will do.',
#   'date': '2024-01-12'},
#  {'id': 62,
#   'datetime': '2024-01-12 10:26:09',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'confirmed the issue is with frontend and we are working on a resolution, next update in 3',
#   'date': '2024-01-12'},
#  {'id': 63,
#   'datetime': '2024-01-12 10:26:37',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Daniel Shay can you revert the changes, before you do, is it safe to rollback?',
#   'date': '2024-01-12'},
#  {'id': 64,
#   'datetime': '2024-01-12 10:27:11',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Tanya can you provide your finding on the payment change?',
#   'date': '2024-01-12'},
#  {'id': 65,
#   'datetime': '2024-01-12 10:27:34',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Which changes should we revert first?',
#   'date': '2024-01-12'},
#  {'id': 66,
#   'datetime': '2024-01-12 10:28:02',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Payment service looks healthy',
#   'date': '2024-01-12'},
#  {'id': 67,
#   'datetime': '2024-01-12 10:28:20',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'the frontend changes, CHG89348. Can you confirm whether it is safe to rollback?',
#   'date': '2024-01-12'},
#  {'id': 68,
#   'datetime': '2024-01-12 10:28:45',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Thank you Tanya, in the meantime can you also check the infra status.',
#   'date': '2024-01-12'},
#  {'id': 69,
#   'datetime': '2024-01-12 10:29:09',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'yea i think it is safe to rollback the changes',
#   'date': '2024-01-12'},
#  {'id': 70,
#   'datetime': '2024-01-12 10:29:29',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': "I'll check the infrastructure status and get back to you.",
#   'date': '2024-01-12'},
#  {'id': 71,
#   'datetime': '2024-01-12 10:29:31',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Daniel please revert the changes, keep us posted on the progress',
#   'date': '2024-01-12'},
#  {'id': 72,
#   'datetime': '2024-01-12 10:29:55',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Rollback already initiated for CHG89348, monitoring the situation.',
#   'date': '2024-01-12'},
#  {'id': 73,
#   'datetime': '2024-01-12 10:30:25',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'the change CHG89348 is cause of the incident and we are reverting the changes, the services will be restored soon.',
#   'date': '2024-01-12'},
#  {'id': 74,
#   'datetime': '2024-01-12 10:30:57',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'I can see the user activity returning to normal',
#   'date': '2024-01-12'},
#  {'id': 75,
#   'datetime': '2024-01-12 10:31:28',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Bob can you confirm the issue is resolved?',
#   'date': '2024-01-12'},
#  {'id': 76,
#   'datetime': '2024-01-12 10:31:49',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Shay can you run a quick sanity test to confirm the rollback',
#   'date': '2024-01-12'},
#  {'id': 77,
#   'datetime': '2024-01-12 10:31:54',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Start drill retro and feedback',
#   'date': '2024-01-12'},
#  {'id': 78,
#   'datetime': '2024-01-12 10:32:00',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Customers are now able to use the site and place orders.',
#   'date': '2024-01-12'},
#  {'id': 79,
#   'datetime': '2024-01-12 10:32:12',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Thank you Bob',
#   'date': '2024-01-12'},
#  {'id': 80,
#   'datetime': '2024-01-12 10:32:38',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'The issue is resovled. rollback of the CHG89348 restored the service',
#   'date': '2024-01-12'},
#  {'id': 81,
#   'datetime': '2024-01-12 10:32:55',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Thanks so much for helping to resolve this! Make sure to communicate the resolution in business channel.',
#   'date': '2024-01-12'},
#  {'id': 82,
#   'datetime': '2024-01-12 10:33:06',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Daniel make sure, to find a root cause before re-deploying the change.',
#   'date': '2024-01-12'},
#  {'id': 83,
#   'datetime': '2024-01-12 10:33:10',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Thanks all',
#   'date': '2024-01-12'},
#  {'id': 84,
#   'datetime': '2024-01-12 10:33:12',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Clicked Start_feedback button',
#   'date': '2024-01-12'},
#  {'id': 85,
#   'datetime': '2024-01-12 10:34:03',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Clicked Start_feedback button',
#   'date': '2024-01-12'},
#  {'id': 86,
#   'datetime': '2024-01-12 10:36:15',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Clicked Start_feedback button',
#   'date': '2024-01-12'},
#  {'id': 87,
#   'datetime': '2024-01-12 10:36:33',
#   'player': 'gamunu@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Clicked Start_feedback button',
#   'date': '2024-01-12'},
#  {'id': 88,
#   'datetime': '2024-01-12 10:38:43',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1454.0,
#   'message': 'Submission successful',
#   'date': '2024-01-12'},
#  {'id': 89,
#   'datetime': '2024-01-12 10:39:50',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Start Drill',
#   'date': '2024-01-12'},
#  {'id': 90,
#   'datetime': '2024-01-12 10:41:05',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Clicked Start button',
#   'date': '2024-01-12'},
#  {'id': 91,
#   'datetime': '2024-01-12 10:41:06',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'date': '2024-01-12'},
#  {'id': 92,
#   'datetime': '2024-01-12 10:41:13',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Please make sure systems are healthy so we can hit target.',
#   'date': '2024-01-12'},
#  {'id': 93,
#   'datetime': '2024-01-12 10:41:17',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Welcome to the team @Drew Lennon. everone is here to help, how are you finding things so far?',
#   'date': '2024-01-12'},
#  {'id': 94,
#   'datetime': '2024-01-12 10:41:23',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'date': '2024-01-12'},
#  {'id': 95,
#   'datetime': '2024-01-12 10:41:26',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Yes @Drew Lennon is incident manager today, Drew Lennon can you drive this?',
#   'date': '2024-01-12'},
#  {'id': 96,
#   'datetime': '2024-01-12 10:41:30',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Hello everyone',
#   'date': '2024-01-12'},
#  {'id': 97,
#   'datetime': '2024-01-12 10:41:36',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'date': '2024-01-12'},
#  {'id': 98,
#   'datetime': '2024-01-12 10:41:38',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'it could be a load issue',
#   'date': '2024-01-12'},
#  {'id': 99,
#   'datetime': '2024-01-12 10:41:40',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'There were a few deployments this morning',
#   'date': '2024-01-12'},
#  {'id': 100,
#   'datetime': '2024-01-12 10:41:44',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "I'm at your service",
#   'date': '2024-01-12'},
#  {'id': 101,
#   'datetime': '2024-01-12 10:41:46',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "I'm online too",
#   'date': '2024-01-12'},
#  {'id': 102,
#   'datetime': '2024-01-12 10:41:48',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'yes im on call',
#   'date': '2024-01-12'},
#  {'id': 103,
#   'datetime': '2024-01-12 10:41:56',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'What do I need to tell the angry customers?',
#   'date': '2024-01-12'},
#  {'id': 104,
#   'datetime': '2024-01-12 10:42:09',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'alright daniel can you check the platform?',
#   'date': '2024-01-12'},
#  {'id': 105,
#   'datetime': '2024-01-12 10:42:27',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Bob how many reports?',
#   'date': '2024-01-12'},
#  {'id': 106,
#   'datetime': '2024-01-12 10:42:58',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'im going to check the platform myself',
#   'date': '2024-01-12'},
#  {'id': 107,
#   'datetime': '2024-01-12 10:43:21',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'im getting a 503 error, anyone else?',
#   'date': '2024-01-12'},
#  {'id': 108,
#   'datetime': '2024-01-12 10:44:17',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': '@bb',
#   'date': '2024-01-12'},
#  {'id': 109,
#   'datetime': '2024-01-12 10:44:24',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Bob?',
#   'date': '2024-01-12'},
#  {'id': 110,
#   'datetime': '2024-01-12 10:44:57',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'We are getting multiple reports from customers',
#   'date': '2024-01-12'},
#  {'id': 111,
#   'datetime': '2024-01-12 10:45:18',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'how many Bob?',
#   'date': '2024-01-12'},
#  {'id': 112,
#   'datetime': '2024-01-12 10:45:53',
#   'player': 'drew.lennon',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': '*Incident Number INC100017:* Sev 1 customer unable to access the platform',
#   'date': '2024-01-12'},
#  {'id': 113,
#   'datetime': '2024-01-12 10:46:18',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "I'm currently experiencing issues with the website; I'm looking into it.",
#   'date': '2024-01-12'},
#  {'id': 114,
#   'datetime': '2024-01-12 10:46:20',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'im seeing low user activity',
#   'date': '2024-01-12'},
#  {'id': 115,
#   'datetime': '2024-01-12 10:46:27',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'in the logs',
#   'date': '2024-01-12'},
#  {'id': 116,
#   'datetime': '2024-01-12 10:46:49',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "We've received multiple reports. It's a widespread problem.",
#   'date': '2024-01-12'},
#  {'id': 117,
#   'datetime': '2024-01-12 10:46:57',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Daniel can you check recent changes?',
#   'date': '2024-01-12'},
#  {'id': 118,
#   'datetime': '2024-01-12 10:47:19',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'still investigating root cause of outage will update in 4 mins',
#   'date': '2024-01-12'},
#  {'id': 119,
#   'datetime': '2024-01-12 10:47:34',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'The most recent changes are CHG89348 and CHG89350 according to logs.',
#   'date': '2024-01-12'},
#  {'id': 120,
#   'datetime': '2024-01-12 10:47:47',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'thanks Bob',
#   'date': '2024-01-12'},
#  {'id': 121,
#   'datetime': '2024-01-12 10:48:23',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "You're welcome. Keep us informed on your progress.",
#   'date': '2024-01-12'},
#  {'id': 122,
#   'datetime': '2024-01-12 10:48:23',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'given that no one can access the platform it could be a frontend issue, any thoughts Daniel?',
#   'date': '2024-01-12'},
#  {'id': 123,
#   'datetime': '2024-01-12 10:48:59',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Tanya can you check that everythings  ok on the network side?',
#   'date': '2024-01-12'},
#  {'id': 124,
#   'datetime': '2024-01-12 10:49:29',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'The frontend service is having issues. Looks unhealthy.',
#   'date': '2024-01-12'},
#  {'id': 125,
#   'datetime': '2024-01-12 10:49:55',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'CHG89348 can you invesitgate this frontend change Daniel',
#   'date': '2024-01-12'},
#  {'id': 126,
#   'datetime': '2024-01-12 10:50:27',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'the frontend services is currently experiencing issues, working on a fix',
#   'date': '2024-01-12'},
#  {'id': 127,
#   'datetime': '2024-01-12 10:50:52',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Bob can anyone access the platform at all?',
#   'date': '2024-01-12'},
#  {'id': 128,
#   'datetime': '2024-01-12 10:50:54',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'I will look into the network infrastructure and get back to you in a bit',
#   'date': '2024-01-12'},
#  {'id': 129,
#   'datetime': '2024-01-12 10:51:25',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Reports coming from everywhere, global outage',
#   'date': '2024-01-12'},
#  {'id': 130,
#   'datetime': '2024-01-12 10:51:48',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "Issues detected in the frontend service. I'll report back with more details shortly.",
#   'date': '2024-01-12'},
#  {'id': 131,
#   'datetime': '2024-01-12 10:51:55',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'thanks Tanya',
#   'date': '2024-01-12'},
#  {'id': 132,
#   'datetime': '2024-01-12 10:52:34',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Daniel can you check if the frontend change i mentioned earlier is safe to rollback?',
#   'date': '2024-01-12'},
#  {'id': 133,
#   'datetime': '2024-01-12 10:52:51',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Hamed you online?',
#   'date': '2024-01-12'},
#  {'id': 134,
#   'datetime': '2024-01-12 10:53:21',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': "Network is looking good, I don't see any alerts or any sort of errors in our monitoring system.",
#   'date': '2024-01-12'},
#  {'id': 135,
#   'datetime': '2024-01-12 10:53:34',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Bob tell the customers that we are currently working on getting a fix',
#   'date': '2024-01-12'},
#  {'id': 136,
#   'datetime': '2024-01-12 10:53:43',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'thanks Tanya',
#   'date': '2024-01-12'},
#  {'id': 137,
#   'datetime': '2024-01-12 10:53:54',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Daniel any update?',
#   'date': '2024-01-12'},
#  {'id': 138,
#   'datetime': '2024-01-12 10:54:03',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'I think the frontend service is having issues after the changes we did.',
#   'date': '2024-01-12'},
#  {'id': 139,
#   'datetime': '2024-01-12 10:54:47',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'can we investigate the change CHG89348, roll it back if its safe to do so',
#   'date': '2024-01-12'},
#  {'id': 140,
#   'datetime': '2024-01-12 10:54:48',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Ok, I will keep customers posted on the progress. Thank you!',
#   'date': '2024-01-12'},
#  {'id': 141,
#   'datetime': '2024-01-12 10:55:38',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Daniel you there?',
#   'date': '2024-01-12'},
#  {'id': 142,
#   'datetime': '2024-01-12 10:56:15',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Frontend down from recent changes that were made to the services',
#   'date': '2024-01-12'},
#  {'id': 143,
#   'datetime': '2024-01-12 10:56:23',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'yes, frontend changes are safe to roll back.',
#   'date': '2024-01-12'},
#  {'id': 144,
#   'datetime': '2024-01-12 10:56:53',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Daniel rollback frontend changes',
#   'date': '2024-01-12'},
#  {'id': 145,
#   'datetime': '2024-01-12 10:57:00',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Rollback for the frontend service has been executed.',
#   'date': '2024-01-12'},
#  {'id': 146,
#   'datetime': '2024-01-12 10:57:38',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Bob can you check with the customers?',
#   'date': '2024-01-12'},
#  {'id': 147,
#   'datetime': '2024-01-12 10:57:44',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': '@danei',
#   'date': '2024-01-12'},
#  {'id': 148,
#   'datetime': '2024-01-12 10:58:00',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Daniel can you check the status of the frontend?',
#   'date': '2024-01-12'},
#  {'id': 149,
#   'datetime': '2024-01-12 10:58:24',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'platform is back working for me',
#   'date': '2024-01-12'},
#  {'id': 150,
#   'datetime': '2024-01-12 10:58:41',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'performed rollback of frontend change',
#   'date': '2024-01-12'},
#  {'id': 151,
#   'datetime': '2024-01-12 10:58:46',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'platform is back online',
#   'date': '2024-01-12'},
#  {'id': 152,
#   'datetime': '2024-01-12 10:59:07',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Frontend running smoothly, orders are coming through :thumbsup:',
#   'date': '2024-01-12'},
#  {'id': 153,
#   'datetime': '2024-01-12 10:59:29',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'thanks, Bob any update?',
#   'date': '2024-01-12'},
#  {'id': 154,
#   'datetime': '2024-01-12 11:00:09',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Customers are reporting they can access the website now, everything is looking good. :thumbsup:',
#   'date': '2024-01-12'},
#  {'id': 155,
#   'datetime': '2024-01-12 11:00:22',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'The frontend service looks healthy.',
#   'date': '2024-01-12'},
#  {'id': 156,
#   'datetime': '2024-01-12 11:00:27',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'good',
#   'date': '2024-01-12'},
#  {'id': 157,
#   'datetime': '2024-01-12 11:00:28',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Customers are reporting that they can access the platform now.',
#   'date': '2024-01-12'},
#  {'id': 158,
#   'datetime': '2024-01-12 11:00:32',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'well done team',
#   'date': '2024-01-12'},
#  {'id': 159,
#   'datetime': '2024-01-12 11:00:53',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'reports coming in from customers, platform is back online for everyone',
#   'date': '2024-01-12'},
#  {'id': 160,
#   'datetime': '2024-01-12 11:01:14',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Start drill retro and feedback',
#   'date': '2024-01-12'},
#  {'id': 161,
#   'datetime': '2024-01-12 11:01:17',
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Clicked Start_feedback button',
#   'date': '2024-01-12'},
#  {'id': 162,
#   'datetime': '2024-01-12 11:02:47',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1455.0,
#   'message': 'Submission successful',
#   'date': '2024-01-12'},
#  {'id': 163,
#   'datetime': '2024-01-12 12:34:20',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Start Drill',
#   'date': '2024-01-12'},
#  {'id': 164,
#   'datetime': '2024-01-12 12:35:48',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Clicked Start button',
#   'date': '2024-01-12'},
#  {'id': 165,
#   'datetime': '2024-01-12 12:35:48',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'date': '2024-01-12'},
#  {'id': 166,
#   'datetime': '2024-01-12 12:35:55',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Please make sure systems are healthy so we can hit target.',
#   'date': '2024-01-12'},
#  {'id': 167,
#   'datetime': '2024-01-12 12:35:59',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Welcome to the team @Eduards Stalmaconoks. everone is here to help, how are you finding things so far?',
#   'date': '2024-01-12'},
#  {'id': 168,
#   'datetime': '2024-01-12 12:36:05',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'date': '2024-01-12'},
#  {'id': 169,
#   'datetime': '2024-01-12 12:36:08',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Yes @Eduards Stalmaconoks is incident manager today, Eduards Stalmaconoks can you drive this?',
#   'date': '2024-01-12'},
#  {'id': 170,
#   'datetime': '2024-01-12 12:36:18',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'date': '2024-01-12'},
#  {'id': 171,
#   'datetime': '2024-01-12 12:36:20',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'it could be a load issue',
#   'date': '2024-01-12'},
#  {'id': 172,
#   'datetime': '2024-01-12 12:36:22',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'There were a few deployments this morning',
#   'date': '2024-01-12'},
#  {'id': 173,
#   'datetime': '2024-01-12 12:36:26',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': "I'm at your service",
#   'date': '2024-01-12'},
#  {'id': 174,
#   'datetime': '2024-01-12 12:36:28',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': "I'm online too",
#   'date': '2024-01-12'},
#  {'id': 175,
#   'datetime': '2024-01-12 12:36:36',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'i will look into this',
#   'date': '2024-01-12'},
#  {'id': 176,
#   'datetime': '2024-01-12 12:36:38',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'What do I need to tell the angry customers?',
#   'date': '2024-01-12'},
#  {'id': 177,
#   'datetime': '2024-01-12 12:37:00',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'we will have system up and running in no time',
#   'date': '2024-01-12'},
#  {'id': 178,
#   'datetime': '2024-01-12 12:37:19',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'how many customers were affected by this?',
#   'date': '2024-01-12'},
#  {'id': 179,
#   'datetime': '2024-01-12 12:37:33',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': "The impact is global, so it's significant. We need to continue addressing this as a priority.",
#   'date': '2024-01-12'},
#  {'id': 180,
#   'datetime': '2024-01-12 12:39:08',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'i can see there were few deployments done this morning, Tanya can you check health of your deployment?',
#   'date': '2024-01-12'},
#  {'id': 181,
#   'datetime': '2024-01-12 12:39:32',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Will check the payment service health and update you shortly',
#   'date': '2024-01-12'},
#  {'id': 182,
#   'datetime': '2024-01-12 12:40:37',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': "What's the status with the incident? any updates?",
#   'date': '2024-01-12'},
#  {'id': 183,
#   'datetime': '2024-01-12 12:40:55',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'still working on it, will keep you posted if we find out something',
#   'date': '2024-01-12'},
#  {'id': 184,
#   'datetime': '2024-01-12 12:41:28',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'The payment service looks healthy on my end',
#   'date': '2024-01-12'},
#  {'id': 185,
#   'datetime': '2024-01-12 12:42:19',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'good. i can see there was another deployment done this morning that could have had an impact on system. Daniel can you check status of your deployment please',
#   'date': '2024-01-12'},
#  {'id': 186,
#   'datetime': '2024-01-12 12:42:55',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'yes changes were made to frontend. the service is having issues and looks unhealthy.',
#   'date': '2024-01-12'},
#  {'id': 187,
#   'datetime': '2024-01-12 12:43:38',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'can you rollback your deployment changes and see if that fixes the problem, thanks',
#   'date': '2024-01-12'},
#  {'id': 188,
#   'datetime': '2024-01-12 12:44:02',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Initiating rollback of the frontend changes now.',
#   'date': '2024-01-12'},
#  {'id': 189,
#   'datetime': '2024-01-12 12:44:40',
#   'player': 'redseds@gmail.com',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Tinus it looks like service is up and running again',
#   'date': '2024-01-12'},
#  {'id': 190,
#   'datetime': '2024-01-12 12:45:29',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 12.0,
#   'session_id': 1456.0,
#   'message': 'Good job on fixing the issue promptly',
#   'date': '2024-01-12'},
#  {'id': 191,
#   'datetime': '2024-01-12 12:45:41',
# ...
#  {'id': 599,
#   'datetime': '2024-01-18 14:05:21',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "Great! that's it then",
#   'date': '2024-01-18'},
#  {'id': 600,
#   'datetime': '2024-01-18 14:05:25',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Good luck, Stay on it sales team',
#   'date': '2024-01-18'},
#  {'id': 601,
#   'datetime': '2024-01-18 14:05:32',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "Ah, I've seen alerts on ad-service",
#   'date': '2024-01-18'},
#  {'id': 602,
#   'datetime': '2024-01-18 14:05:35',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'They look quite worrying',
#   'date': '2024-01-18'},
#  {'id': 603,
#   'datetime': '2024-01-18 14:05:36',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Guys, big problem!!',
#   'date': '2024-01-18'},
#  {'id': 604,
#   'datetime': '2024-01-18 14:05:40',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "I've got reports from multiple users that they can't access the site",
#   'date': '2024-01-18'},
#  {'id': 605,
#   'datetime': '2024-01-18 14:05:44',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Tell Bob!',
#   'date': '2024-01-18'},
#  {'id': 606,
#   'datetime': '2024-01-18 14:05:46',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "Looks like we've got a random site failure",
#   'date': '2024-01-18'},
#  {'id': 607,
#   'datetime': '2024-01-18 14:05:50',
#   'player': 'Tinus',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'the load was quite high, could be a load issue',
#   'date': '2024-01-18'},
#  {'id': 608,
#   'datetime': '2024-01-18 14:05:58',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Checking those alerts for adservice...',
#   'date': '2024-01-18'},
#  {'id': 609,
#   'datetime': '2024-01-18 14:06:02',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "what's going on? what do I need to do",
#   'date': '2024-01-18'},
#  {'id': 610,
#   'datetime': '2024-01-18 14:06:04',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'I made a change to that last sprint... let me check',
#   'date': '2024-01-18'},
#  {'id': 611,
#   'datetime': '2024-01-18 14:06:08',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "Guys someone tell me what's happening",
#   'date': '2024-01-18'},
#  {'id': 612,
#   'datetime': '2024-01-18 14:06:11',
#   'player': 'Bez',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "Let's not ruin this good day",
#   'date': '2024-01-18'},
#  {'id': 613,
#   'datetime': '2024-01-18 14:06:13',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Adservice is not running!',
#   'date': '2024-01-18'},
#  {'id': 614,
#   'datetime': '2024-01-18 14:06:16',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "We're on it Bez!",
#   'date': '2024-01-18'},
#  {'id': 615,
#   'datetime': '2024-01-18 14:07:03',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'i was able to place an order',
#   'date': '2024-01-18'},
#  {'id': 616,
#   'datetime': '2024-01-18 14:07:10',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'anyone else?',
#   'date': '2024-01-18'},
#  {'id': 617,
#   'datetime': '2024-01-18 14:07:24',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Checking',
#   'date': '2024-01-18'},
#  {'id': 618,
#   'datetime': '2024-01-18 14:08:12',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'im also able to place an order',
#   'date': '2024-01-18'},
#  {'id': 619,
#   'datetime': '2024-01-18 14:08:15',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'I could place an order too',
#   'date': '2024-01-18'},
#  {'id': 620,
#   'datetime': '2024-01-18 14:08:29',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Can someone explain what adservice has to do with placing an order?',
#   'date': '2024-01-18'},
#  {'id': 621,
#   'datetime': '2024-01-18 14:08:46',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Checking last changes',
#   'date': '2024-01-18'},
#  {'id': 622,
#   'datetime': '2024-01-18 14:08:47',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Anything you would like me to look at?',
#   'date': '2024-01-18'},
#  {'id': 623,
#   'datetime': '2024-01-18 14:09:57',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'nothing, i was just checking on what bob was saying about multiple users not being able to access site',
#   'date': '2024-01-18'},
#  {'id': 624,
#   'datetime': '2024-01-18 14:10:09',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'I can see two recern changes to PROD.\nDaniel, can you tell me if you think `CHG89357` might cause the issue?',
#   'date': '2024-01-18'},
#  {'id': 625,
#   'datetime': '2024-01-18 14:10:25',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'so i tested the frontend and placed a order',
#   'date': '2024-01-18'},
#  {'id': 626,
#   'datetime': '2024-01-18 14:10:31',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':alarm_clock: - You are 6 minutes in have you qualified the problem? You can type `/help` if you need any reminders.',
#   'date': '2024-01-18'},
#  {'id': 627,
#   'datetime': '2024-01-18 14:11:04',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'it is possible, need more time to be sure',
#   'date': '2024-01-18'},
#  {'id': 628,
#   'datetime': '2024-01-18 14:11:13',
#   'player': 'aydin.ghane',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': '*Incident Number INC100094:* SEV3 adservice down',
#   'date': '2024-01-18'},
#  {'id': 629,
#   'datetime': '2024-01-18 14:11:13',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':star: Incident record created',
#   'date': '2024-01-18'},
#  {'id': 630,
#   'datetime': '2024-01-18 14:11:15',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':star: Send first comms in first 5 minutes',
#   'date': '2024-01-18'},
#  {'id': 631,
#   'datetime': '2024-01-18 14:11:44',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "We have reports that adservice is down.\nWe couldn't reproduce the issue however.\nWe're on it.",
#   'date': '2024-01-18'},
#  {'id': 632,
#   'datetime': '2024-01-18 14:12:23',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Is that change you put in to do with recommendation service?',
#   'date': '2024-01-18'},
#  {'id': 633,
#   'datetime': '2024-01-18 14:12:47',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':bulb: Asking questions to validate impact of the problem"',
#   'date': '2024-01-18'},
#  {'id': 634,
#   'datetime': '2024-01-18 14:13:22',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'ad-service is down but it is non-customer impacting',
#   'date': '2024-01-18'},
#  {'id': 635,
#   'datetime': '2024-01-18 14:14:07',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'getting more reports about customers not being able to access the platform',
#   'date': '2024-01-18'},
#  {'id': 636,
#   'datetime': '2024-01-18 14:14:32',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':alarm_clock: - Half your time is up, stay focused. You can type `/help` if you need any reminders.',
#   'date': '2024-01-18'},
#  {'id': 637,
#   'datetime': '2024-01-18 14:14:38',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Are we dealing with 2 issues?',
#   'date': '2024-01-18'},
#  {'id': 638,
#   'datetime': '2024-01-18 14:15:10',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "Seems like it,\nI'm still waiting for the answer how adservices could be related to placing an answer.",
#   'date': '2024-01-18'},
#  {'id': 639,
#   'datetime': '2024-01-18 14:15:52',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'just checked CHG89357:RecommendationService:version 1.8  change and its not causing any issues on the ad-service',
#   'date': '2024-01-18'},
#  {'id': 640,
#   'datetime': '2024-01-18 14:16:37',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "If adservice doesn't have an impact on customers, is it something we'd want to roll back? Tanya",
#   'date': '2024-01-18'},
#  {'id': 641,
#   'datetime': '2024-01-18 14:16:44',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'ad-service is non customer impacting, so we are currently experiencing some other issue as well',
#   'date': '2024-01-18'},
#  {'id': 642,
#   'datetime': '2024-01-18 14:17:15',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': "Daniel Can you elaborate what's the other issue?",
#   'date': '2024-01-18'},
#  {'id': 643,
#   'datetime': '2024-01-18 14:17:30',
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'yeah we can roll the change back, but we also still need to figure out what this other issue is',
#   'date': '2024-01-18'},
#  {'id': 644,
#   'datetime': '2024-01-18 14:17:52',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Can anyone else reproduce the problem with accessing the platform?',
#   'date': '2024-01-18'},
#  {'id': 645,
#   'datetime': '2024-01-18 14:18:10',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'im not sure but bob mentioned customers not being able to access the website',
#   'date': '2024-01-18'},
#  {'id': 646,
#   'datetime': '2024-01-18 14:18:20',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'We do have some dorp on user activity in the past 15 mins',
#   'date': '2024-01-18'},
#  {'id': 647,
#   'datetime': '2024-01-18 14:18:41',
#   'player': 'Shay',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'no i cant reproduce the problem',
#   'date': '2024-01-18'},
#  {'id': 648,
#   'datetime': '2024-01-18 14:18:55',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'yeah the platform works just fine for me',
#   'date': '2024-01-18'},
#  {'id': 649,
#   'datetime': '2024-01-18 14:19:31',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':bulb: Hint: Check the organisation chart to see who the right person to ask is. Use `/help and press org chart.',
#   'date': '2024-01-18'},
#  {'id': 650,
#   'datetime': '2024-01-18 14:19:48',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'ok my reports all seem to be coming from europe direction ',
#   'date': '2024-01-18'},
#  {'id': 651,
#   'datetime': '2024-01-18 14:20:32',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':alarm_clock: - You have less than 4 minutes. You can type `/help` if you need any reminders.',
#   'date': '2024-01-18'},
#  {'id': 652,
#   'datetime': '2024-01-18 14:20:43',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'anywhere specific @Bob?',
#   'date': '2024-01-18'},
#  {'id': 653,
#   'datetime': '2024-01-18 14:21:26',
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Ive pinpointed that all of the complaints seem to be from Frankfurt Germany',
#   'date': '2024-01-18'},
#  {'id': 654,
#   'datetime': '2024-01-18 14:22:26',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':bulb: Hint: Fully understand scope of the problem',
#   'date': '2024-01-18'},
#  {'id': 655,
#   'datetime': '2024-01-18 14:22:32',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': ':alarm_clock: - You have less than 2 minutes remaining, remember communication is key. You can type `/help` if you need any reminders.',
#   'date': '2024-01-18'},
#  {'id': 656,
#   'datetime': '2024-01-18 14:23:29',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'unless its a 3rd party issue',
#   'date': '2024-01-18'},
#  {'id': 657,
#   'datetime': '2024-01-18 14:23:45',
#   'player': 'Daniel',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'what do you think @aydin?',
#   'date': '2024-01-18'},
#  {'id': 658,
#   'datetime': '2024-01-18 14:24:28',
#   'player': 'aydin.ghane@albelli.com',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'I think I wait for the trainers to explain to me what would the irght questions to ask in situation like this :wink:',
#   'date': '2024-01-18'},
#  {'id': 659,
#   'datetime': '2024-01-18 14:24:42',
#   'player': 'UptimeLabs',
#   'scenario': 'online-boutique',
#   'level': 4.0,
#   'session_id': 1464.0,
#   'message': 'Start retro and feedback',
#   'date': '2024-01-18'},
#  {'id': 660,
#   'datetime': '2024-01-17 10:50:56',
#   'player': 'Slackbot',
#   'scenario': None,
#   'level': None,
#   'session_id': None,
#   'message': 'Conail Tierney archived the channel <https://uptimelabs-metaverse.slack.com/archives/C06D8JA7PJS|#ob-inc1449>',
#   'date': '2024-01-17'},
#  {'id': 661,
#   'datetime': '2024-01-18 11:36:42',
#   'player': 'Slackbot',
#   'scenario': None,
#   'level': None,
#   'session_id': None,
#   'message': 'Conail Tierney archived the channel <https://uptimelabs-metaverse.slack.com/archives/C06AV97GG1E|#ob-inc1403>',
#   'date': '2024-01-18'},
#  {'id': 662,
#   'datetime': '2024-01-18 11:37:16',
#   'player': 'Slackbot',
#   'scenario': None,
#   'level': None,
#   'session_id': None,
#   'message': 'Conail Tierney archived the channel <https://uptimelabs-metaverse.slack.com/archives/C069RV7AHC7|#ob-business-comms1403>',
#   'date': '2024-01-18'},
#  {'id': 663,
#   'datetime': '2024-01-18 16:02:04',
#   'player': 'UptimeLabs',
#   'scenario': None,
#   'level': None,
#   'session_id': None,
#   'message': 'New User has registered',
#   'date': '2024-01-18'}]

# %%
#get unique session_ids from data set
sessions = set(map(lambda m:
        m['session_id'], input_json))

#filter any null sessions
sessions = [id for id in sessions if id != None]

#create an array of dicts. 1 for each session
sessions = list(map(lambda s:
                   {'session_id' : s}, sessions))

#place session data within each session dict
for session in sessions:
    #get messages for the session
    messages = list(filter(lambda m:
                     m['session_id'] == session['session_id'] , input_json))
    
    #place messages within the session dict
    session['messages'] = messages
    
    #elevate level and date to the root of the dict
    session['level'] = messages[0]['level']
    session['date'] = messages[0]['date']
    
    #remove unnecessary keys from the message dict now they've been moved to the dict root
    session['messages'] = list(map(lambda m: {
        'id': m['id'],
        'player': m['player'],    
        'message': m['message'],
        'datetime': m['datetime']
    }, session['messages']))
    
    #determine message type for stars and hints
    for message in session['messages']:
        if message['player'] == "UptimeLabs":
            if ":star:" in message['message']:
                message_type = "star"
                print("found star")
            elif ":bulb:" in message['message']:
                message_type = "hint"
            elif ":alarm_clock:" in message['message']:
                message_type = "timer"
            else:
                message_type = "message"
        else:
            message_type = "message"
        message['type'] = message_type
        message['message'] = emoji.emojize(message['message'], language='alias')
    
    #get all the message times to create min and max times for the session
    message_times = list(map(lambda m:
                         m['datetime'],session['messages']))
    session['start'] = min(message_times)
    session['end'] = max(message_times)
    
    #add a convenient list of unique players to the session for use in vis groupings
    session['players'] = list(set(map(lambda m:
                         m['player'],session['messages'])))
    
    #add mentions to each message
    for message in session['messages']:
        mentions = []
        for player in session['players']:
            if player.lower() in message['message'].lower():
                mentions.append(player);
        message['mentions'] = mentions

json_sessions = json.dumps(sessions)
json_sessions
# Out:
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# found star
# '[{"session_id": 1453.0, "messages": [{"id": 0, "player": "Bez", "message": "Hey team!\\ud83d\\ude80 Can you believe it\'s been 8 fantastic years for Online Boutique?", "datetime": "2024-01-12 09:41:32", "type": "message", "mentions": []}, {"id": 1, "player": "Bez", "message": " Before we dive into anniversary celebrations, let\'s give a warm welcome to Maya, our new Security Analyst. She\'s got 5 years of cybersecurity expertise under her belt! \\ud83d\\udc4f ", "datetime": "2024-01-12 09:41:36", "type": "message", "mentions": ["Maya"]}, {"id": 2, "player": "Maya", "message": "Hi everyone! \\ud83d\\udd90\\ufe0f Thrilled to be here, especially on such a special occasion. Let\'s make Online Boutique even successful and secure together!", "datetime": "2024-01-12 09:41:41", "type": "message", "mentions": []}, {"id": 3, "player": "Tinus", "message": "Welcome, Maya! Your experience will elevate our cybersecurity efforts.", "datetime": "2024-01-12 09:41:44", "type": "message", "mentions": ["Maya"]}, {"id": 4, "player": "Tanya", "message": "Excited to have you, Maya! Bez has been very excited to have you on the team.", "datetime": "2024-01-12 09:41:48", "type": "message", "mentions": ["Bez", "Maya"]}, {"id": 5, "player": "Daniel", "message": "Impressive! Eager to learn from you, Maya.", "datetime": "2024-01-12 09:41:51", "type": "message", "mentions": ["Maya"]}, {"id": 6, "player": "Shay", "message": "\\ud83d\\udc4d Welcome Maya, pleasure meeting you.", "datetime": "2024-01-12 09:41:55", "type": "message", "mentions": ["Maya"]}, {"id": 7, "player": "Bob", "message": "Hi Maya! Your experience is top-notch. Cheers to you and to Online Boutique\'s 8-year anniversary! \\ud83e\\udd73 \\ud83c\\udf89", "datetime": "2024-01-12 09:41:58", "type": "message", "mentions": ["Maya"]}, {"id": 8, "player": "Maya", "message": "Thanks for the warm welcome! Excited for the celebration and our anniversary party.", "datetime": "2024-01-12 09:42:01", "type": "message", "mentions": []}, {"id": 9, "player": "UptimeLabs", "message": "Start lvl 18", "datetime": "2024-01-12 09:42:11", "type": "message", "mentions": []}, {"id": 10, "player": "conail@uptimelabs.io", "message": "Clicked Start button", "datetime": "2024-01-12 09:42:19", "type": "message", "mentions": []}, {"id": 11, "player": "Bez", "message": "We are all so glad you have joined us Maya", "datetime": "2024-01-12 09:42:21", "type": "message", "mentions": ["Maya"]}, {"id": 12, "player": "Tinus", "message": "Hold on, team. Quick check-in. Is anyone else experiencing internet problems or slow connectivity?", "datetime": "2024-01-12 09:42:23", "type": "message", "mentions": []}, {"id": 13, "player": "Shay", "message": "Internet\'s definitely sluggish, was loading up github and it took ages to load", "datetime": "2024-01-12 09:42:26", "type": "message", "mentions": []}, {"id": 14, "player": "Bez", "message": "Perhaps it could be due to the increase of sales we have been having with this anniversary sale?", "datetime": "2024-01-12 09:42:29", "type": "message", "mentions": []}, {"id": 15, "player": "Hamed", "message": "Hey team, we\'ve seen some weird traffic from our data centre network in the last couple of days, it\'s been mostly minor but never as bad compared to now although", "datetime": "2024-01-12 09:42:31", "type": "message", "mentions": []}, {"id": 16, "player": "Tanya", "message": "Hamed and I will have been monitoring outbound traffic. Checking for anomalies again.", "datetime": "2024-01-12 09:42:35", "type": "message", "mentions": ["Hamed"]}, {"id": 17, "player": "Daniel", "message": "I will try to place an order and check the platform.", "datetime": "2024-01-12 09:42:42", "type": "message", "mentions": []}, {"id": 18, "player": "Shay", "message": "Just ran a test on my internet speed.", "datetime": "2024-01-12 09:42:52", "type": "message", "mentions": []}, {"id": 19, "player": "Shay", "message": " ", "datetime": "2024-01-12 09:42:55", "type": "message", "mentions": []}, {"id": 20, "player":  ...

# %% [markdown]
# {"id":5609,
# "datetime":"2023-09-07 07:47:25.867",
# "player":"UptimeLabs",
# "scenario":"online-boutique",
# "level":1.0,
# "session_id":1000.0,
# "message":"UptimeLabs has joined the channel",
# "date":"2023-09-07"}

# %%
output_json
# Out:
# [{'message': 'Start Drill', 'player': 'UptimeLabs', 'datetime': '2024-01-11'},
#  {'message': 'Clicked Start button',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Please make sure systems are healthy so we can hit target.',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Welcome to the team @Hamed S. everone is here to help, how are you finding things so far?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Yes @Hamed S is incident manager today, Hamed S can you drive this?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'it could be a load issue',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'There were a few deployments this morning',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'Tinus, leave it with me',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "I'm at your service",
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': "I'm online too", 'player': 'Tanya', 'datetime': '2024-01-11'},
#  {'message': 'What do I need to tell the angry customers?',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob, wht do we know about the reports?',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Can you be more specific?',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob can you please be more specific?',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "Understood. We're receiving multiple complaints. Double-check and confirm there's an urgent issue in production.",
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': "We've got a spike in complaints, seems like a serious issue. Urgent attention needed.",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'The issue has been confirmed. Frontend service is degraded. Stay focused and work with the team to resolve it quickly.',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Issues detected in the frontend service. It looks unhealthy.',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob can please be more specific?',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob can please be more specific?',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Let me check with customers and get screenshots',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob can please be more specific?',
#   'player': 'hamed@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'What information do you exactly need?',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Start Drill', 'player': 'UptimeLabs', 'datetime': '2024-01-11'},
#  {'message': 'Clicked Start button',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Please make sure systems are healthy so we can hit target.',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Welcome to the team @Charlene Quinn. everone is here to help, how are you finding things so far?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Yes @Charlene Quinn is incident manager today, Charlene Quinn can you drive this?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'yes my team will take a look into it',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'it could be a load issue',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'There were a few deployments this morning',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': "I'm at your service",
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': "I'm online too", 'player': 'Tanya', 'datetime': '2024-01-11'},
#  {'message': 'What do I need to tell the angry customers?',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'yes i can see user activity is down',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'is anyone else getting error503 when trying to access the site?',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "It's not just you. We've got multiple reports of error 503.\xa0",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': '*Incident Number INC100040:* error with accessing website',
#   'player': 'charlene',
#   'datetime': '2024-01-11'},
#  {'message': ':star: Reproduces the incident',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': ':star: Incident record is created',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': "Tinus whats the update I'm getting worried here",
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Charlene Quinn is on it will up date you asap',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'ok need a prgress update asap',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Tanya Shay have you made any recent changes to the site',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Bez currently looking into if any recent changes have caused the issue',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Yes, I recently deployed a new version of the payment service, change number CHG89350. For the frontend service, Daniel was responsible for the latest update, change number CHG89348.\xa0',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'brill thanks for the update',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'right now the priority is getting the site functional',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'is it possible to rollback these new changes Tanya',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Understood. We should focus on restoring service as quickly as possible. Keep me posted on your findings.',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'have identified the potential issue, will keep you informed',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'yes Tinus',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'which change should i do first?',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': "daniel's change since it's the most recent one",
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Tanya any update?',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'CHG89348 was recently changed according to logs.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'can you give me a change number to rollback',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': "yes, my working theory CHG89348 is currently causing the issues with the site as there wasn't any issues reported when tanya deployed the new payment service",
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'yes CHG89348 Tanya',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'ok rolling back frontend now',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'thank you Tanya',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "Tinus we're doing a rollback on some changes which should restore us back to the last stable version of the site",
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Noted, rollback in progress. Keep me updated on the status post-rollback.',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'Tinus just check the site and everything seems to be up and running again',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'rollback complete', 'player': 'Tanya', 'datetime': '2024-01-11'},
#  {'message': 'the issue has been resolved',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'The frontend service is back up and working. Site looks healthy.',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'thank you Tanya',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks so much for helping to resolve this!',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': "You're welcome.", 'player': 'Tanya', 'datetime': '2024-01-11'},
#  {'message': 'Tinus no more issues being reported?',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Systems are running smoothly, orders are coming through :thumbsup:',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'good to hear',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'great job Tanya',
#   'player': 'charlene@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "Hey team!:rocket: Can you believe it's been 8 fantastic years for Online Boutique?",
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': " Before we dive into anniversary celebrations, let's give a warm welcome to Maya, our new Security Analyst. She's got 5 years of cybersecurity expertise under her belt! :clap: ",
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': "Hi everyone! :raised_hand_with_fingers_splayed: Thrilled to be here, especially on such a special occasion. Let's make Online Boutique even successful and secure together!",
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Welcome, Maya! Your experience will elevate our cybersecurity efforts.',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'Excited to have you, Maya! Bez has been very excited to have you on the team.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'Impressive! Eager to learn from you, Maya.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': ':+1: Welcome Maya, pleasure meeting you.',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': "Hi Maya! Your experience is top-notch. Cheers to you and to Online Boutique's 8-year anniversary! :partying_face: :tada:",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks for the warm welcome! Excited for the celebration and our anniversary party.',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Start lvl 18', 'player': 'UptimeLabs', 'datetime': '2024-01-11'},
#  {'message': 'Clicked Start button',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'We are all so glad you have joined us Maya',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Hold on, team. Quick check-in. Is anyone else experiencing internet problems or slow connectivity?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': "Internet's definitely sluggish",
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'Perhaps it could be due to the increase of sales we have been having with this anniversary sale?',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': "Hey team, we've seen some weird traffic from our data centre network in the last couple of days, but it's not a big deal. We've had this kind of thing happen before",
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'Hamed and I will have been monitoring outbound traffic. Checking for anomalies again.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'Feels like a repeat. Outbound traffic acting up. Investigating.',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'I will try to place an order.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'I will need a couple of minutes to get myself set up to help the team feel free to ask me for anything when I return.',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': "Hey team!:rocket: Can you believe it's been 8 fantastic years for Online Boutique?",
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': " Before we dive into anniversary celebrations, let's give a warm welcome to Maya, our new Security Analyst. She's got 5 years of cybersecurity expertise under her belt! :clap: ",
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': "Hi everyone! :raised_hand_with_fingers_splayed: Thrilled to be here, especially on such a special occasion. Let's make Online Boutique even successful and secure together!",
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Welcome, Maya! Your experience will elevate our cybersecurity efforts.',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'Excited to have you, Maya! Bez has been very excited to have you on the team.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'Impressive! Eager to learn from you, Maya.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': ':+1: Welcome Maya, pleasure meeting you.',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': "Hi Maya! Your experience is top-notch. Cheers to you and to Online Boutique's 8-year anniversary! :partying_face: :tada:",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks for the warm welcome! Excited for the celebration and our anniversary party.',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Start lvl 18', 'player': 'UptimeLabs', 'datetime': '2024-01-11'},
#  {'message': 'Clicked Start button',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'We are all so glad you have joined us Maya',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Hold on, team. Quick check-in. Is anyone else experiencing internet problems or slow connectivity?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': "Internet's definitely sluggish, was loading up github and it took ages to load",
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'Perhaps it could be due to the increase of sales we have been having with this anniversary sale?',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': "Hey team, we've seen some weird traffic from our data centre network in the last couple of days, it's been mostly minor but never as bad compared to now although",
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'Hamed and I will have been monitoring outbound traffic. Checking for anomalies again.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'I will try to place an order and check the platform.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'Just ran a test on my internet speed.',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': ' ', 'player': 'Shay', 'datetime': '2024-01-11'},
#  {'message': "Hey team!:rocket: Can you believe it's been 8 fantastic years for Online Boutique?",
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': " Before we dive into anniversary celebrations, let's give a warm welcome to Maya, our new Security Analyst. She's got 5 years of cybersecurity expertise under her belt! :clap: ",
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': "Hi everyone! :raised_hand_with_fingers_splayed: Thrilled to be here, especially on such a special occasion. Let's make Online Boutique even successful and secure together!",
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Welcome, Maya! Your experience will elevate our cybersecurity efforts.',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'Excited to have you, Maya! Bez has been very excited to have you on the team.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'Impressive! Eager to learn from you, Maya.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': ':+1: Welcome Maya, pleasure meeting you.',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': "Hi Maya! Your experience is top-notch. Cheers to you and to Online Boutique's 8-year anniversary! :partying_face: :tada:",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks for the warm welcome! Excited for the celebration and our anniversary party.',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Start lvl 18', 'player': 'UptimeLabs', 'datetime': '2024-01-11'},
#  {'message': 'Clicked Start button',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'We are all so glad you have joined us Maya',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Hold on, team. Quick check-in. Is anyone else experiencing internet problems or slow connectivity?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': "Internet's definitely sluggish, was loading up github and it took ages to load",
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'Perhaps it could be due to the increase of sales we have been having with this anniversary sale?',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': "Hey team, we've seen some weird traffic from our data centre network in the last couple of days, it's been mostly minor but never as bad compared to now although",
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'Hamed and I will have been monitoring outbound traffic. Checking for anomalies again.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'I will try to place an order and check the platform.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'Just ran a test on my internet speed.',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': ' ', 'player': 'Shay', 'datetime': '2024-01-11'},
#  {'message': 'Drew Lennon',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Hamed is this affecting customers?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob, any reports of slowness from customers?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'im sure as of now maybe Bob can help',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'Or is this just affecting internal users at uptime?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'getting mutiple reports checking through them now and will give you an update',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': "Bob what's the news on this internet slowness? do we have a prod incident affecting customers?",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': '*Incident Number INC100021:* SEV1 website slowness, we are investigating',
#   'player': 'stuart',
#   'datetime': '2024-01-11'},
#  {'message': "Getting multiple complaints about timeouts when booting up the website\nSome customer are experiencing long loading times and delays\nOther customers aren't experiencing any issues at all.\n",
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks Bob is there any pattern to the people experiencing slowness?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Want me to look at anything',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'Perhaps certain countries or customer types?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'maybe it is because of our anniversary sale',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'Hey Shay yes please can you look at the logs to see if there are any clues as to this slowness issue?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Shay do we have high server utilisation?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'i can confirm that the reports seem to be coming globally from everywhere',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'not just specific to one region',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'not seeing any pattern no',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': "Ok thanks, I've raised a sev 1 incident, I'll keep everyone informed of progress",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'yeah i can check now',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'thanks Shay, let me know if you need me to escalate',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'There is a spike in outbound connections in the edge router and the origin ip block 10.50.0.0/24. That ip range is the same as the ip block the frontend and payments are hosted on.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'im not getting any issue on my end',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'platform working fine for me',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks Tanya, so it might be a network routing or switch issue? Are you able to advise on this?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Daniel I wonder why its working for you. any ideas?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'im not sure as of yet will keep you informed',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'Just an update to confirm that we are getting reports of slowness globally. Sees to be affecting lots of users but not all',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Just got a security alert seeing a significant increase in outbound network traffic',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Can anyone else relicate this issue internally?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'thanks Maya yes, seems to be causing slowness affecting users',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'i havent no, i can check the recent changes perhaps but im really not sure',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'Are you able to hep diagnose Maya?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Daniel yes please, check the recent changes for me',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'i  might need help figuring why im getting this alert',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': "Ok Maya, who's best to escale to? Hamed?",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'we do have high user server utilisation but im not an network expert we could have a lot of users on at the moment',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'Hamed are you able to help Maya diagnose this issue?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'yes Hamed S Tanya can you help',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': ':alarm_clock: - You are 6 minutes in have you qualified the problem? You can type `/help` if you need any reminders.',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': 'on it maya', 'player': 'Tanya', 'datetime': '2024-01-11'},
#  {'message': 'yeah will jump on call now maya',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': "Update - we're looking at high outbound network traffic. Next update in 5 mins",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks Hamed',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'network security scan nearly complete',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'network security scan is complete and our issues all seem to be relating to our network switch trying to figure out what exactly.',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'thanks Maya, Hamed can you help advise Maya please?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'oh no our network switch causing DDoS (Distributed Denial of Service) attacks, intermittently dropping packets.',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'Seems problems relate to a network switch. Next update in 5 mins',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "The disruptions in outbound connections are affecting our internal company's users and the external global customer base.",
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'Great Hamed, what do you advise?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'i suggest we restart the switch',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks Maya, Hamed do you agree',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "Affecting users internally and globally. We're discussing restarting a network switch",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': ':alarm_clock: - Half your time is up, stay focused. You can type `/help` if you need any reminders.',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': 'i will need time to investigate about the restart or we can perform it now. Its your choice',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': "I'd just like to understand the implications of restarting the switch. If it's safe then lets do it",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'i think its the best option',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'hmm im not sure but it could make the platform worse',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'Hamed, tell me more',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'will need time to investigate with maya',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'Hamed what other options do we have?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'restarting could bring down one of our services',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': "Hamed ok, please keep me updated, I'll communicate our plan",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Your right restarting the switch isnt the best option as it might intruduce some more issues',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': " Trying to think of another solution but i'm not too familiar with the network infrastructure here at OB",
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'No worries Maya I can send over the graph of the network infra if you wanna look at it',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'That would be perfect Hamed S',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': ' ', 'player': 'Hamed', 'datetime': '2024-01-11'},
#  {'message': "we're currently investigating the implications of restarting the switch. Next update within the next few minutes",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Looking at the diagram now, will need a moment to figure out what to do next',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'oh im noticing a backup switch',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'is that backup switch mibehaving? or can we switch over to the backup?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'yeah just checked the back-up switch seems to be safe from the ddos',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': 'we can alter internet traffic to redirect through the backup switch, bypassing the infected switch.',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'OK sounds like a good plan. Lets do that',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': "I'll communicate the plan",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'i can change it over now',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': ':alarm_clock: - You have less than 4 minutes. You can type `/help` if you need any reminders.',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': "we're going to fail-over to our redundant switch which should solve the problem. Next update in a few minutes",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'the infected switch has been successfully changed over',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Good job, can we confirm stuart rimell rimell?',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks Maya',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob is the issue fixed?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'ill check my connection now',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'checking', 'player': 'Bob', 'datetime': '2024-01-11'},
#  {'message': 'thanks guys',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'get new reports coming in now',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Bob new reports? what are they saying?',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Platform seems to be working again for everyone',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': ':alarm_clock: - You have less than 2 minutes remaining, remember communication is key. You can type `/help` if you need any reminders.',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': "ok looks ike we've solved the problem for now. THis'll be an interesting PIR for sure.",
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'yes my internet is back running full speed again',
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'Cheers, everyone! Resolving these network issues added a bit of spice to our celebration',
#   'player': 'Tanya',
#   'datetime': '2024-01-11'},
#  {'message': 'Good job team! We managed to keep the anniversary vibe alive despite the detour.',
#   'player': 'Tinus',
#   'datetime': '2024-01-11'},
#  {'message': 'High-fives all around!  I will take out that faulty switch as soon as possible.',
#   'player': 'Hamed',
#   'datetime': '2024-01-11'},
#  {'message': "The website's performance is looking solid again ",
#   'player': 'Shay',
#   'datetime': '2024-01-11'},
#  {'message': 'The anniversary orders are flowing smoothly now. No hiccups on the code side.',
#   'player': 'Daniel',
#   'datetime': '2024-01-11'},
#  {'message': 'Our customers are back to enjoying the celebration. Happy customers, happy anniversary!',
#   'player': 'Bob',
#   'datetime': '2024-01-11'},
#  {'message': 'Incident solved. Traffic and utilisation returning to normal. More news expected after the PIR',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Really great job stuart rimell rimell.',
#   'player': 'Maya',
#   'datetime': '2024-01-11'},
#  {'message': 'Special congratulations to our Incident Manager for steering the ship with finesse and to Maya for your help identifying the faulty switch. Cheers to a remarkable team! :tada:',
#   'player': 'Bez',
#   'datetime': '2024-01-11'},
#  {'message': 'Thanks everyone, great work team!',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Start drill retro and feedback',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': 'Clicked Start_feedback button',
#   'player': 'stuart@uptimelabs.io',
#   'datetime': '2024-01-11'},
#  {'message': 'Submission successful',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-11'},
#  {'message': "Hey team!:rocket: Can you believe it's been 8 fantastic years for Online Boutique?",
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': " Before we dive into anniversary celebrations, let's give a warm welcome to Maya, our new Security Analyst. She's got 5 years of cybersecurity expertise under her belt! :clap: ",
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': "Hi everyone! :raised_hand_with_fingers_splayed: Thrilled to be here, especially on such a special occasion. Let's make Online Boutique even successful and secure together!",
#   'player': 'Maya',
#   'datetime': '2024-01-12'},
#  {'message': 'Welcome, Maya! Your experience will elevate our cybersecurity efforts.',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'Excited to have you, Maya! Bez has been very excited to have you on the team.',
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'Impressive! Eager to learn from you, Maya.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': ':+1: Welcome Maya, pleasure meeting you.',
#   'player': 'Shay',
#   'datetime': '2024-01-12'},
#  {'message': "Hi Maya! Your experience is top-notch. Cheers to you and to Online Boutique's 8-year anniversary! :partying_face: :tada:",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Thanks for the warm welcome! Excited for the celebration and our anniversary party.',
#   'player': 'Maya',
#   'datetime': '2024-01-12'},
#  {'message': 'Start lvl 18', 'player': 'UptimeLabs', 'datetime': '2024-01-12'},
#  {'message': 'Clicked Start button',
#   'player': 'conail@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'We are all so glad you have joined us Maya',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Hold on, team. Quick check-in. Is anyone else experiencing internet problems or slow connectivity?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': "Internet's definitely sluggish, was loading up github and it took ages to load",
#   'player': 'Shay',
#   'datetime': '2024-01-12'},
#  {'message': 'Perhaps it could be due to the increase of sales we have been having with this anniversary sale?',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': "Hey team, we've seen some weird traffic from our data centre network in the last couple of days, it's been mostly minor but never as bad compared to now although",
#   'player': 'Hamed',
#   'datetime': '2024-01-12'},
#  {'message': 'Hamed and I will have been monitoring outbound traffic. Checking for anomalies again.',
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'I will try to place an order and check the platform.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Just ran a test on my internet speed.',
#   'player': 'Shay',
#   'datetime': '2024-01-12'},
#  {'message': ' ', 'player': 'Shay', 'datetime': '2024-01-12'},
#  {'message': 'the infected switch has been successfully changed over',
#   'player': 'Maya',
#   'datetime': '2024-01-12'},
#  {'message': 'Good job, can we confirm @Conail Tierney?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'Cheers, everyone! Resolving these network issues added a bit of spice to our celebration',
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'Good job team! We managed to keep the anniversary vibe alive despite the detour.',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'High-fives all around!  I will take out that faulty switch as soon as possible.',
#   'player': 'Hamed',
#   'datetime': '2024-01-12'},
#  {'message': "The website's performance is looking solid again ",
#   'player': 'Shay',
#   'datetime': '2024-01-12'},
#  {'message': 'The anniversary orders are flowing smoothly now. No hiccups on the code side.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Our customers are back to enjoying the celebration. Happy customers, happy anniversary!',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Really great job @Conail Tierney.',
#   'player': 'Maya',
#   'datetime': '2024-01-12'},
#  {'message': 'Special congratulations to our Incident Manager for steering the ship with finesse and to Maya for your help identifying the faulty switch. Cheers to a remarkable team! :tada:',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Start drill retro and feedback',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-12'},
#  {'message': 'Start Drill', 'player': 'UptimeLabs', 'datetime': '2024-01-12'},
#  {'message': 'Clicked Start button',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Please make sure systems are healthy so we can hit target.',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Welcome to the team @Gamunu Balagalla. everone is here to help, how are you finding things so far?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Yes @Gamunu Balagalla is incident manager today, Gamunu Balagalla can you drive this?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'it could be a load issue',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'Hey, team, how are we doing?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'There were a few deployments this morning',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "I'm at your service",
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "I'm online too", 'player': 'Tanya', 'datetime': '2024-01-12'},
#  {'message': 'What do I need to tell the angry customers?',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'yes Tinus will keep you updated in the business comms channel',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel what were the deployments, were you involved in the changes?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob, how many customers are impacted? What are they reporting?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'I made changes to the frontend service',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "Reports are coming in from various locations indicating widespread issues with the frontend. Customers are experiencing difficulties with navigation and checkout. We're seeing a high volume of tickets on this.",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'ok Daniel can you look into the changes you made and verify everything is working? maybe run quick sanity test',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': "I'll check the frontend service and report back shortly.",
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob are the reports coming from all regions? or specific to UK?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'The reports of issues are widespread, not limited to any specific region.',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Tanya can you check the change CHG89350?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': '*Incident Number INC100056:* SEV-1 incident, frontend down.',
#   'player': 'gamunu',
#   'datetime': '2024-01-12'},
#  {'message': "Will do. I'll review the payment service changes and get back to you.",
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'team is investigating the cause of the issue and will provide an update in 5min',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel please update us with your findings',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Review complete and frontend looks unhealthy at the moment',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob keep eye on the business comms. I will update you about the progress in there so you can keep the customers informed',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'thanks will do.', 'player': 'Bob', 'datetime': '2024-01-12'},
#  {'message': 'confirmed the issue is with frontend and we are working on a resolution, next update in 3',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel Shay can you revert the changes, before you do, is it safe to rollback?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Tanya can you provide your finding on the payment change?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Which changes should we revert first?',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Payment service looks healthy',
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'the frontend changes, CHG89348. Can you confirm whether it is safe to rollback?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Thank you Tanya, in the meantime can you also check the infra status.',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'yea i think it is safe to rollback the changes',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "I'll check the infrastructure status and get back to you.",
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel please revert the changes, keep us posted on the progress',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Rollback already initiated for CHG89348, monitoring the situation.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'the change CHG89348 is cause of the incident and we are reverting the changes, the services will be restored soon.',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'I can see the user activity returning to normal',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob can you confirm the issue is resolved?',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Shay can you run a quick sanity test to confirm the rollback',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Start drill retro and feedback',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-12'},
#  {'message': 'Customers are now able to use the site and place orders.',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Thank you Bob',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'The issue is resovled. rollback of the CHG89348 restored the service',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Thanks so much for helping to resolve this! Make sure to communicate the resolution in business channel.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel make sure, to find a root cause before re-deploying the change.',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Thanks all',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Clicked Start_feedback button',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Clicked Start_feedback button',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Clicked Start_feedback button',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Clicked Start_feedback button',
#   'player': 'gamunu@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Submission successful',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-12'},
#  {'message': 'Start Drill', 'player': 'UptimeLabs', 'datetime': '2024-01-12'},
#  {'message': 'Clicked Start button',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Please make sure systems are healthy so we can hit target.',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Welcome to the team @Drew Lennon. everone is here to help, how are you finding things so far?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Yes @Drew Lennon is incident manager today, Drew Lennon can you drive this?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'Hello everyone',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'it could be a load issue',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'There were a few deployments this morning',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "I'm at your service",
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "I'm online too", 'player': 'Tanya', 'datetime': '2024-01-12'},
#  {'message': 'yes im on call',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'What do I need to tell the angry customers?',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'alright daniel can you check the platform?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob how many reports?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'im going to check the platform myself',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'im getting a 503 error, anyone else?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': '@bb',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'We are getting multiple reports from customers',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'how many Bob?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': '*Incident Number INC100017:* Sev 1 customer unable to access the platform',
#   'player': 'drew.lennon',
#   'datetime': '2024-01-12'},
#  {'message': "I'm currently experiencing issues with the website; I'm looking into it.",
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'im seeing low user activity',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'in the logs',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': "We've received multiple reports. It's a widespread problem.",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel can you check recent changes?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'still investigating root cause of outage will update in 4 mins',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'The most recent changes are CHG89348 and CHG89350 according to logs.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'thanks Bob',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': "You're welcome. Keep us informed on your progress.",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'given that no one can access the platform it could be a frontend issue, any thoughts Daniel?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Tanya can you check that everythings  ok on the network side?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'The frontend service is having issues. Looks unhealthy.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'CHG89348 can you invesitgate this frontend change Daniel',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'the frontend services is currently experiencing issues, working on a fix',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob can anyone access the platform at all?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'I will look into the network infrastructure and get back to you in a bit',
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'Reports coming from everywhere, global outage',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': "Issues detected in the frontend service. I'll report back with more details shortly.",
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'thanks Tanya',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel can you check if the frontend change i mentioned earlier is safe to rollback?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Hamed you online?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': "Network is looking good, I don't see any alerts or any sort of errors in our monitoring system.",
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob tell the customers that we are currently working on getting a fix',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'thanks Tanya',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel any update?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'I think the frontend service is having issues after the changes we did.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'can we investigate the change CHG89348, roll it back if its safe to do so',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Ok, I will keep customers posted on the progress. Thank you!',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel you there?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Frontend down from recent changes that were made to the services',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'yes, frontend changes are safe to roll back.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel rollback frontend changes',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Rollback for the frontend service has been executed.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Bob can you check with the customers?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': '@danei',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Daniel can you check the status of the frontend?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'platform is back working for me',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'performed rollback of frontend change',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'platform is back online',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Frontend running smoothly, orders are coming through :thumbsup:',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'thanks, Bob any update?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Customers are reporting they can access the website now, everything is looking good. :thumbsup:',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'The frontend service looks healthy.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'good',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Customers are reporting that they can access the platform now.',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'well done team',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'reports coming in from customers, platform is back online for everyone',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Start drill retro and feedback',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-12'},
#  {'message': 'Clicked Start_feedback button',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-12'},
#  {'message': 'Submission successful',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-12'},
#  {'message': 'Start Drill', 'player': 'UptimeLabs', 'datetime': '2024-01-12'},
#  {'message': 'Clicked Start button',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Please make sure systems are healthy so we can hit target.',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'Welcome to the team @Eduards Stalmaconoks. everone is here to help, how are you finding things so far?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': "@Tinus we're starting to get some mixed reports of customers not able to access the site, can your team investigate?",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'Yes @Eduards Stalmaconoks is incident manager today, Eduards Stalmaconoks can you drive this?',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'Hey folks, what is going on? I can see a big drop on payments hitting our accounts',
#   'player': 'Bez',
#   'datetime': '2024-01-12'},
#  {'message': 'it could be a load issue',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'There were a few deployments this morning',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "I'm at your service",
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': "I'm online too", 'player': 'Tanya', 'datetime': '2024-01-12'},
#  {'message': 'i will look into this',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'What do I need to tell the angry customers?',
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'we will have system up and running in no time',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'how many customers were affected by this?',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': "The impact is global, so it's significant. We need to continue addressing this as a priority.",
#   'player': 'Bob',
#   'datetime': '2024-01-12'},
#  {'message': 'i can see there were few deployments done this morning, Tanya can you check health of your deployment?',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'Will check the payment service health and update you shortly',
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': "What's the status with the incident? any updates?",
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': 'still working on it, will keep you posted if we find out something',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'The payment service looks healthy on my end',
#   'player': 'Tanya',
#   'datetime': '2024-01-12'},
#  {'message': 'good. i can see there was another deployment done this morning that could have had an impact on system. Daniel can you check status of your deployment please',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'yes changes were made to frontend. the service is having issues and looks unhealthy.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'can you rollback your deployment changes and see if that fixes the problem, thanks',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'Initiating rollback of the frontend changes now.',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Tinus it looks like service is up and running again',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'Good job on fixing the issue promptly',
#   'player': 'Tinus',
#   'datetime': '2024-01-12'},
#  {'message': '*Incident Number INC100098:* unable to access the site',
#   'player': 'redseds',
#   'datetime': '2024-01-12'},
#  {'message': 'no probs',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'Systems are running smoothly, orders are coming through :thumbsup:',
#   'player': 'Daniel',
#   'datetime': '2024-01-12'},
#  {'message': 'Start drill retro and feedback',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-12'},
#  {'message': 'Clicked Start_feedback button',
#   'player': 'redseds@gmail.com',
#   'datetime': '2024-01-12'},
#  {'message': 'Submission successful',
#   'player': 'UptimeLabs',
#   'datetime': '2024-01-12'}]

# %%
# Serializing json
json_object = json.dumps(output_json)
 
# Writing to sample.json
with open("session.js", "w") as outfile:
    outfile.write(json_object)

# %% [markdown]
# [
#     {
#         "session_id": 1000,
#         "messages": [
#             {
#                 "message": "UptimeLabs has joined the channel",
#                 "player": "UptimeLabs",
#                 "datetime": "2023-09-07T06:47:25.867Z"
#             },
#             {
#                 "message": "UptimeLabs has joined the channel",
#                 "player": "UptimeLabs",
#                 "datetime": "2023-09-07T06:47:25.925Z"
#             }...
# ...
# ]

# %%
json_object
# Out:
# '[{"message": "Start Drill", "player": "UptimeLabs", "datetime": "2024-01-11"}, {"message": "Clicked Start button", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.", "player": "Bez", "datetime": "2024-01-11"}, {"message": "Please make sure systems are healthy so we can hit target.", "player": "Bez", "datetime": "2024-01-11"}, {"message": "Welcome to the team @Hamed S. everone is here to help, how are you finding things so far?", "player": "Tinus", "datetime": "2024-01-11"}, {"message": "@Tinus we\'re starting to get some mixed reports of customers not able to access the site, can your team investigate?", "player": "Bob", "datetime": "2024-01-11"}, {"message": "Yes @Hamed S is incident manager today, Hamed S can you drive this?", "player": "Tinus", "datetime": "2024-01-11"}, {"message": "Hey folks, what is going on? I can see a big drop on payments hitting our accounts", "player": "Bez", "datetime": "2024-01-11"}, {"message": "it could be a load issue", "player": "Tinus", "datetime": "2024-01-11"}, {"message": "There were a few deployments this morning", "player": "Daniel", "datetime": "2024-01-11"}, {"message": "Tinus, leave it with me", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "I\'m at your service", "player": "Daniel", "datetime": "2024-01-11"}, {"message": "I\'m online too", "player": "Tanya", "datetime": "2024-01-11"}, {"message": "What do I need to tell the angry customers?", "player": "Bob", "datetime": "2024-01-11"}, {"message": "Bob, wht do we know about the reports?", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "Can you be more specific?", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "Bob can you please be more specific?", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "Understood. We\'re receiving multiple complaints. Double-check and confirm there\'s an urgent issue in production.", "player": "Tinus", "datetime": "2024-01-11"}, {"message": "We\'ve got a spike in complaints, seems like a serious issue. Urgent attention needed.", "player": "Bob", "datetime": "2024-01-11"}, {"message": "The issue has been confirmed. Frontend service is degraded. Stay focused and work with the team to resolve it quickly.", "player": "Bez", "datetime": "2024-01-11"}, {"message": "Issues detected in the frontend service. It looks unhealthy.", "player": "Bob", "datetime": "2024-01-11"}, {"message": "Bob can please be more specific?", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "Bob can please be more specific?", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "Let me check with customers and get screenshots", "player": "Bob", "datetime": "2024-01-11"}, {"message": "Bob can please be more specific?", "player": "hamed@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "What information do you exactly need?", "player": "Bob", "datetime": "2024-01-11"}, {"message": "Start Drill", "player": "UptimeLabs", "datetime": "2024-01-11"}, {"message": "Clicked Start button", "player": "charlene@uptimelabs.io", "datetime": "2024-01-11"}, {"message": "So, business wise, we are on target for this months sales. Having said that we are too close to the target. We need every penny of every minute to stay on course.", "player": "Bez", "datetime": "2024-01-11"}, {"message": "Please make sure systems are healthy so we can hit target.", "player": "Bez", "datetime": "2024-01-11"}, {"message": "Welcome to the team @Charlene Quinn. everone is here to help, how are you finding things so far?", "player": "Tinus", "datetime": "2024-01-11"}, {"message": "@Tinus we\'re starting to get some mixed reports of customers not able to access the site, can your team investigate?", "player": "Bob", "datetime": "2024-01-11"}, {"mess ...
